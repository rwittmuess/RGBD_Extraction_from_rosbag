# %% [markdown]
# # Little guide on how to use the functions

# %% [markdown]
# ## bag2image

# %%
import bag2image

bag_file = 'test3.bag'


# Show available topics 
print(bag2image.getTopics(bag_file))

# Get Image Data
image_data = bag2image.getImageData(bag_file, '/d455/depth/image_rect_raw')
print("Frames: ", len(image_data))

# Show k-th image
k = 0
bag2image.dispImg(image_data[k])
# TODO: WHY 2 pictures ?!
# Out:
# ['/d455/accel/imu_info', '/d455/depth/camera_info', '/d455/depth/image_rect_raw', '/d455/extrinsics/depth_to_infra1', '/d455/extrinsics/depth_to_infra2', '/d455/gyro/imu_info', '/d455/imu', '/d455/infra1/camera_info', '/d455/infra1/image_rect_raw', '/d455/infra2/camera_info', '/d455/infra2/image_rect_raw', '/d455/motion_module/parameter_descriptions', '/d455/motion_module/parameter_updates', '/d455/realsense2_camera_manager/bond', '/d455/rgb_camera/parameter_descriptions', '/d455/rgb_camera/parameter_updates', '/d455/stereo_module/auto_exposure_roi/parameter_descriptions', '/d455/stereo_module/auto_exposure_roi/parameter_updates', '/d455/stereo_module/parameter_descriptions', '/d455/stereo_module/parameter_updates', '/diagnostics', '/drone_status', '/mavlink/from', '/mavlink/gcs_ip', '/mavros/altitude', '/mavros/battery', '/mavros/estimator_status', '/mavros/extended_state', '/mavros/geofence/waypoints', '/mavros/imu/data', '/mavros/imu/data_raw', '/mavros/imu/mag', '/mavros/imu/stat
# ...
